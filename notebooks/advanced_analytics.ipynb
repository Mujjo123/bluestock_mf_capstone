# %% [markdown]
# # Day 6: Advanced Analytics and Risk Metrics
#
# This notebook runs the Day 6 advanced analytics workflow for the Bluestock Mutual Fund Analytics Capstone. It computes benchmark alpha/beta, Sharpe/Sortino ratios, VaR 95%, and drawdown summaries.

# %%
import pandas as pd
from pathlib import Path
import sys

ROOT = Path('..').resolve() if Path('..').exists() else Path('.')
sys.path.insert(0, str(ROOT))
import scripts.advanced_analytics as adv

print('Root folder:', ROOT)

# %%
adv.main()

# %%
output_dir = Path('..') / 'reports' / 'advanced_charts'
results_dir = Path('..') / 'reports'
display('Output files:')
for path in [results_dir / 'alpha_beta_table.csv', results_dir / 'fund_sharpe_ranks.csv', results_dir / 'var_drawdown_summary.csv']:
    print(path, 'exists=' , path.exists())
print('Chart folder exists=', output_dir.exists())

# %% [markdown]
# ## Explore the Results
#
# The generated CSV files are:
# - `reports/alpha_beta_table.csv`
# - `reports/fund_sharpe_ranks.csv`
# - `reports/var_drawdown_summary.csv`
#
# The chart placeholders are saved in `reports/advanced_charts/`. Replace them with real visualizations once the data files are available and the required plotting dependencies are installed.
